# %%
import pandas as pd
from sqlalchemy import create_engine
from config import password
import matplotlib.pyplot as plt

# %%
engine = create_engine(f'postgresql://Deneb:{password}@localhost:5432/SQL-Challenge')
connection = engine.connect()

# %%
salaries = pd.read_sql('SELECT * FROM salaries', connection)
titles = pd.read_sql('SELECT * FROM titles', connection)

# %%
Salaries = salaries.merge(titles, on = "emp_no")

# %%
#Plot histogram
Salaries['salary'].plot.hist(figsize=(14,7))
plt.show()

# %%
#Plot average salary by title
avg = Salaries.groupby(Salaries['title'])['salary'].mean()
avg.plot.bar(figsize=(14,7))
plt.show()

# %%
 #Search for the requested id
 me = Salaries.loc[Salaries['emp_no'] == 499942]
 me
# Out:
#         emp_no  salary from_date_x   to_date_x             title from_date_y  \
# 443224  499942   40000  1998-03-28  1999-03-28  Technique Leader  1998-03-28
#
#          to_date_y
# 443224  9999-01-01
